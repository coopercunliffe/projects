# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('Pokemon.csv', encoding='latin-1')
df.head()
# Out:
#    #        Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1   Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 1  2     Ivysaur  Grass  Poison    405  60      62       63       80       80
# 2  3    Venusaur  Grass  Poison    525  80      82       83      100      100
# 3  4  Charmander   Fire     NaN    309  39      52       43       60       50
# 4  5  Charmeleon   Fire     NaN    405  58      64       58       80       65
#
#    Speed  Stage  Legendary
# 0     45      1      False
# 1     60      2      False
# 2     80      3      False
# 3     65      1      False
# 4     80      2      False

# %%
df.shape
# Out:
# (151, 13)

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Stage', 'Legendary'],
#       dtype='object')

# %%
df_legendaries = df[df['Legendary'] == True]
df_legendaries
# Out:
#        #      Name    Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 143  144  Articuno       Ice  Flying    580   90      85      100       95
# 144  145    Zapdos  Electric  Flying    580   90      90       85      125
# 145  146   Moltres      Fire  Flying    580   90     100       90      125
# 149  150    Mewtwo   Psychic     NaN    680  106     110       90      154
#
#      Sp. Def  Speed  Stage  Legendary
# 143      125     85      1       True
# 144       90    100      1       True
# 145       85     90      1       True
# 149       90    130      1       True

# %%
df_high_attackers = df[df['Attack'] >= 85]
df_high_attackers.shape
# Out:
# (49, 13)

# %%
sns.lmplot(x='Attack', y='Defense', hue='Legendary', fit_reg=False, data=df)

# %%
sns.lmplot(x='Attack', y='Defense', hue='Type 1', fit_reg=False, data=df)

# %%
sns.lmplot(x='Attack', y='Defense', hue='Stage', fit_reg=False, data=df)

# %%
df_small = df[['Attack', 'Defense']]
sns.boxplot(data=df_small)

# %%
df['ADsum'] = df['Attack'] + df['Defense']

# %%
sns.countplot(x='Type 1', data=df)

# %%
# This cell finds the rows that have 'Fairy' in either Type 1 or Type 2

df[(df['Type 1'] == 'Fairy') | (df['Type 2'] == 'Fairy')]
# Out:
#        #        Name   Type 1 Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 34    35    Clefairy    Fairy    NaN    323   70      45       48       60
# 35    36    Clefable    Fairy    NaN    483   95      70       73       95
# 38    39  Jigglypuff   Normal  Fairy    270  115      45       20       45
# 39    40  Wigglytuff   Normal  Fairy    435  140      70       45       85
# 121  122    Mr. Mime  Psychic  Fairy    460   40      45       65      100
#
#      Sp. Def  Speed  Stage  Legendary  ADsum
# 34        65     35      1      False     93
# 35        90     60      2      False    143
# 38        25     20      1      False     65
# 39        50     45      2      False    115
# 121      120     90      1      False    110

# %%
df[df['Stage'] == 1]
# Out:
#        #        Name    Type 1   Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 0      1   Bulbasaur     Grass   Poison    318   45      49       49       65
# 3      4  Charmander      Fire      NaN    309   39      52       43       60
# 6      7    Squirtle     Water      NaN    314   44      48       65       50
# 9     10    Caterpie       Bug      NaN    195   45      30       35       20
# 12    13      Weedle       Bug   Poison    195   40      35       30       20
# 15    16      Pidgey    Normal   Flying    251   40      45       40       35
# 18    19     Rattata    Normal      NaN    253   30      56       35       25
# 20    21     Spearow    Normal   Flying    262   40      60       30       31
# 22    23       Ekans    Poison      NaN    288   35      60       44       40
# 24    25     Pikachu  Electric      NaN    320   35      55       40       50
# 26    27   Sandshrew    Ground      NaN    300   50      75       85       20
# 28    29  NidoranªÛ    Poison      NaN    275   55      47       52       40
# 31    32  Nidoranªâ    Poison      NaN    273   46      57       40       40
# 34    35    Clefairy     Fairy      NaN    323   70      45       48       60
# 36    37      Vulpix      Fire      NaN    299   38      41       40       50
# 38    39  Jigglypuff    Normal    Fairy    270  115      45       20       45
# 40    41       Zubat    Poison   Flying    245   40      45       35       30
# 42    43      Oddish     Grass   Poison    320   45      50       55       75
# 45    46       Paras       Bug    Grass    285   35      70       55       45
# 47    48     Venonat       Bug   Poison    305   60      55       50       40
# 49    50     Diglett    Ground      NaN    265   10      55       25       35
# 51    52      Meowth    Normal      NaN    290   40      45       35       40
# 53    54     Psyduck     Water      NaN    320   50      52       48       65
# 55    56      Mankey  Fighting      NaN    305   40      80       35       35
# 57    58   Growlithe      Fire      NaN    350   55      70       45       70
# 59    60     Poliwag     Water      NaN    300   40      50       40       40
# 62    63        Abra   Psychic      NaN    310   25      20       15      105
# 65    66      Machop  Fighting      NaN    305   70      80       50       35
# 68    69  Bellsprout     Grass   Poison    300   50      75       35       70
# 71    72   Tentacool     Water   Poison    335   40      40       35       50
# ..   ...         ...       ...      ...    ...  ...     ...      ...      ...
# 108  109     Koffing    Poison      NaN    340   40      65       95       60
# 110  111     Rhyhorn    Ground     Rock    345   80      85       95       30
# 112  113     Chansey    Normal      NaN    450  250       5        5       35
# 113  114     Tangela     Grass      NaN    435   65      55      115      100
# 114  115  Kangaskhan    Normal      NaN    490  105      95       80       40
# 115  116      Horsea     Water      NaN    295   30      40       70       70
# 117  118     Goldeen     Water      NaN    320   45      67       60       35
# 119  120      Staryu     Water      NaN    340   30      45       55       70
# 121  122    Mr. Mime   Psychic    Fairy    460   40      45       65      100
# 122  123     Scyther       Bug   Flying    500   70     110       80       55
# 123  124        Jynx       Ice  Psychic    455   65      50       35      115
# 124  125  Electabuzz  Electric      NaN    490   65      83       57       95
# 125  126      Magmar      Fire      NaN    495   65      95       57      100
# 126  127      Pinsir       Bug      NaN    500   65     125      100       55
# 127  128      Tauros    Normal      NaN    490   75     100       95       40
# 128  129    Magikarp     Water      NaN    200   20      10       55       15
# 130  131      Lapras     Water      Ice    535  130      85       80       85
# 131  132       Ditto    Normal      NaN    288   48      48       48       48
# 132  133       Eevee    Normal      NaN    325   55      55       50       45
# 136  137     Porygon    Normal      NaN    395   65      60       70       85
# 137  138     Omanyte      Rock    Water    355   35      40      100       90
# 139  140      Kabuto      Rock    Water    355   30      80       90       55
# 141  142  Aerodactyl      Rock   Flying    515   80     105       65       60
# 142  143     Snorlax    Normal      NaN    540  160     110       65       65
# 143  144    Articuno       Ice   Flying    580   90      85      100       95
# 144  145      Zapdos  Electric   Flying    580   90      90       85      125
# 145  146     Moltres      Fire   Flying    580   90     100       90      125
# 146  147     Dratini    Dragon      NaN    300   41      64       45       50
# 149  150      Mewtwo   Psychic      NaN    680  106     110       90      154
# 150  151         Mew   Psychic      NaN    600  100     100      100      100
#
#      Sp. Def  Speed  Stage  Legendary  ADsum
# 0         65     45      1      False     98
# 3         50     65      1      False     95
# 6         64     43      1      False    113
# 9         20     45      1      False     65
# 12        20     50      1      False     65
# 15        35     56      1      False     85
# 18        35     72      1      False     91
# 20        31     70      1      False     90
# 22        54     55      1      False    104
# 24        50     90      1      False     95
# 26        30     40      1      False    160
# 28        40     41      1      False     99
# 31        40     50      1      False     97
# 34        65     35      1      False     93
# 36        65     65      1      False     81
# 38        25     20      1      False     65
# 40        40     55      1      False     80
# 42        65     30      1      False    105
# 45        55     25      1      False    125
# 47        55     45      1      False    105
# 49        45     95      1      False     80
# 51        40     90      1      False     80
# 53        50     55      1      False    100
# 55        45     70      1      False    115
# 57        50     60      1      False    115
# 59        40     90      1      False     90
# 62        55     90      1      False     35
# 65        35     35      1      False    130
# 68        30     40      1      False    110
# 71       100     70      1      False     75
# ..       ...    ...    ...        ...    ...
# 108       45     35      1      False    160
# 110       30     25      1      False    180
# 112      105     50      1      False     10
# 113       40     60      1      False    170
# 114       80     90      1      False    175
# 115       25     60      1      False    110
# 117       50     63      1      False    127
# 119       55     85      1      False    100
# 121      120     90      1      False    110
# 122       80    105      1      False    190
# 123       95     95      1      False     85
# 124       85    105      1      False    140
# 125       85     93      1      False    152
# 126       70     85      1      False    225
# 127       70    110      1      False    195
# 128       20     80      1      False     65
# 130       95     60      1      False    165
# 131       48     48      1      False     96
# 132       65     55      1      False    105
# 136       75     40      1      False    130
# 137       55     35      1      False    140
# 139       45     55      1      False    170
# 141       75    130      1      False    170
# 142      110     30      1      False    175
# 143      125     85      1       True    185
# 144       90    100      1       True    175
# 145       85     90      1       True    190
# 146       50     50      1      False    109
# 149       90    130      1       True    200
# 150      100    100      1      False    200
#
# [79 rows x 14 columns]
